# %%
from utils import get_data_from_dir

df = get_data_from_dir(max_count_lines=1050)

# %%
df.describe()
# Out:
#         content_len  content_len_without_blank  \
# count  14819.000000               14819.000000
# mean    7220.715500                5324.557190
# std     8877.715544                6511.058737
# min      108.000000                  79.000000
# 25%     1566.000000                1172.000000
# 50%     3565.000000                2641.000000
# 75%     9009.000000                6718.500000
# max    81492.000000               74005.000000
#
#        count_lines_without_blank_lines
# count                     14819.000000
# mean                        170.091977
# std                         199.400113
# min                           6.000000
# 25%                          42.000000
# 50%                          91.000000
# 75%                         217.000000
# max                        1048.000000

# %% [markdown]
# # Время на получение необходимых метаданных работ

# %%
from utils import get_time_to_meta

output = get_time_to_meta(df, 1)
# Out:
# ----------------------------------------
# Not compiled: https://github.com/wention/BeautifulSoup4/blob/master/bs4/__init__.py
# SyntaxError: invalid syntax
# In line 147
# In column 29
# ----------------------------------------
# ----------------------------------------
# Not compiled: https://github.com/wention/BeautifulSoup4/blob/master/bs4/builder/_htmlparser.py
# SyntaxError: invalid syntax
# In line 64
# In column 43
# ----------------------------------------
# ----------------------------------------
# Not compiled: https://github.com/wention/BeautifulSoup4/blob/master/bs4/builder/_lxml.py
# SyntaxError: invalid syntax
# In line 102
# In column 68
# ----------------------------------------
# ----------------------------------------
# Not compiled: https://github.com/wention/BeautifulSoup4/blob/master/bs4/diagnose.py
# SyntaxError: invalid syntax
# In line 18
# In column 11
# ----------------------------------------
# ----------------------------------------
# ...

# %%
from utils import plot_and_save_result

plot_and_save_result(
    df=output,
    xlabel='Строк кода без пустых.',
    ylabel='Время, с.',
    title='Временные затраты получения метаданных работы.',
    what='meta'
)

# %% [markdown]
# # Замер времени быстрого поиска схожих работ с работами длиной 100 и 500 строк

# %%
from utils import get_time_algorithms

output = get_time_algorithms(df, df[df.count_lines_without_blank_lines == 100].iloc[0], iterations=3, metric='fast')
# Out:
# ----------------------------------------
# Not compiled: https://github.com/wention/BeautifulSoup4/blob/master/bs4/__init__.py
# SyntaxError: invalid syntax
# In line 147
# In column 29
# ----------------------------------------
# ----------------------------------------
# Not compiled: https://github.com/wention/BeautifulSoup4/blob/master/bs4/__init__.py
# SyntaxError: invalid syntax
# In line 147
# In column 29
# ----------------------------------------
# ----------------------------------------
# Not compiled: https://github.com/wention/BeautifulSoup4/blob/master/bs4/__init__.py
# SyntaxError: invalid syntax
# In line 147
# In column 29
# ----------------------------------------
# ----------------------------------------
# Not compiled: https://github.com/wention/BeautifulSoup4/blob/master/bs4/builder/_htmlparser.py
# SyntaxError: invalid syntax
# In line 64
# In column 43
# ----------------------------------------
# ----------------------------------------
# ...

# %%
from utils import plot_and_save_result

# Жаккар, операторы, ключевые слова, литералы
plot_and_save_result(
    df=output,
    xlabel='Строк кода без пустых.',
    ylabel='Время, с.',
    title='Быстрый поиск схожих работ с работой длиной в 100 строк.',
    what='fast'
)

# %%
from utils import get_time_algorithms

output = get_time_algorithms(df, df[df.count_lines_without_blank_lines == 500].iloc[0], iterations=3, metric='fast')
# Out:
# ----------------------------------------
# Not compiled: https://github.com/wention/BeautifulSoup4/blob/master/bs4/__init__.py
# SyntaxError: invalid syntax
# In line 147
# In column 29
# ----------------------------------------
# ----------------------------------------
# Not compiled: https://github.com/wention/BeautifulSoup4/blob/master/bs4/__init__.py
# SyntaxError: invalid syntax
# In line 147
# In column 29
# ----------------------------------------
# ----------------------------------------
# Not compiled: https://github.com/wention/BeautifulSoup4/blob/master/bs4/__init__.py
# SyntaxError: invalid syntax
# In line 147
# In column 29
# ----------------------------------------
# ----------------------------------------
# Not compiled: https://github.com/wention/BeautifulSoup4/blob/master/bs4/builder/_htmlparser.py
# SyntaxError: invalid syntax
# In line 64
# In column 43
# ----------------------------------------
# ----------------------------------------
# ...

# %%
from utils import plot_and_save_result

# Жаккар, операторы, ключевые слова, литералы
plot_and_save_result(
    df=output,
    xlabel='Строк кода без пустых.',
    ylabel='Время, с.',
    title='Быстрый поиск схожих работ с работой длиной в 500 строк.',
    what='fast'
)

# %% [markdown]
# # Замер времени поиска схожих фрагментов работ с работами длиной 100 и 500 строк с помощью алгоритма GST

# %%
# Удаляем дубликаты 14 тыс. работ -> 962 работ. 
df.drop_duplicates(subset='count_lines_without_blank_lines', keep='last')
# Out:
#                                                  content  \
# 82     # -*- coding: utf-8 -*-\n"""Beautiful Soup bon...
# 208    # Copyright 2007 Google, Inc. All Rights Reser...
# 245    import collections\nimport enum\nimport warnin...
# 250    """Support for tasks, coroutines and the sched...
# 369    """distutils.command.build_ext\nImplements the...
# ...                                                  ...
# 15679  # Copyright 2019 The TensorFlow Authors. All R...
# 15680  # Copyright 2020 The TensorFlow Authors. All R...
# 15681  #!/usr/bin/env python\n# Copyright (c) 2008-20...
# 15682  from termcolor.termcolor import (\n    ATTRIBU...
# 15683  # Copyright (c) 2008-2011 Volvox Development T...
#
#                                                     link extension  \
# 82     https://github.com/wention/BeautifulSoup4/blob...        py
# 208    https://github.com/python/cpython/blob/main/Li...        py
# 245    https://github.com/python/cpython/blob/main/Li...        py
# ...

# %%
from utils import get_time_algorithms

output = get_time_algorithms(
    df.drop_duplicates(subset='count_lines_without_blank_lines', keep='last'),
    df[df.count_lines_without_blank_lines == 100].iloc[0],
    iterations=2,
    metric='gst'
)
# Out:
# ----------------------------------------
# Not compiled: https://github.com/python/cpython/blob/main/Lib/lib2to3/tests/data/py2_test_grammar.py
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
# In line 25
# In column 30
# ----------------------------------------
# ----------------------------------------
# Not compiled: https://github.com/python/cpython/blob/main/Lib/lib2to3/tests/data/py2_test_grammar.py
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
# In line 25
# In column 30
# ----------------------------------------
# 15683

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from scipy.optimize import curve_fit
from datetime import datetime

def square_func(x, a, b, c):
    return a * x**2 + b * x + c

def cube_func(x, a, b, c, d):
    return a * x**3 + b * x**2 + c * x + d

def quart_func(x, a, b, c, d, e):
    return a * x**4 + b * x**3 + c * x**2 + d * x + e

def plot_and_save_result(df, xlabel, ylabel, title, what,
                         trend='linear'):
    # Simple Moving average
    unique_count_lines = np.unique(df.count_lines)
    mean_times = []
    for i in range(unique_count_lines.shape[0]):
        summ = 0
        count = 0
        for count_line, time in zip(df.count_lines, df.times):
            if unique_count_lines[i] == count_line:
                summ += time
                count += 1
        mean_times.append(summ / count)

    plt.figure(figsize=(12, 12), dpi=80)
    # plt.plot(unique_count_lines, mean_times, label='Среднее')

    if trend == 'linear':
        z = np.polyfit(unique_count_lines, mean_times, 1)
        p = np.poly1d(z)
        plt.plot(unique_count_lines, p(unique_count_lines),"r--", label='Линейный тренд.')
    elif trend == 'n^2':
        popt_cons, _ = curve_fit(square_func, unique_count_lines, mean_times, bounds=([-np.inf, 0., 0.], [np.inf, 0.1 ** 100, 0.1 ** 100]))
        p = np.poly1d(popt_cons)
        plt.plot(unique_count_lines, p(unique_count_lines),"r--", label='Квадратичный тренд.')
    elif trend == 'n^3':
        popt_cons, _ = curve_fit(cube_func, unique_count_lines, mean_times, bounds=([-np.inf, 0., 0., 0.], [np.inf, 0.1 ** 100, 0.1 ** 100, 0.1 ** 100]))
        p = np.poly1d(popt_cons)
        plt.plot(unique_count_lines, p(unique_count_lines),"r--", label='Кубический тренд.')
    elif trend == 'n^4':
        popt_cons, _ = curve_fit(quart_func, unique_count_lines, mean_times, bounds=([-np.inf, 0., 0., 0., 0.], [np.inf, 0.1 ** 100, 0.1 ** 100, 0.1 ** 100, 0.1 ** 100]))
        p = np.poly1d(popt_cons)
        plt.plot(unique_count_lines, p(unique_count_lines),"r--", label='n^4.')

    rolling = pd.DataFrame(
        {
            'unique_count_lines': unique_count_lines,
            'mean_times': mean_times
        }
    )
    num_window = 20
    plt.plot(rolling.unique_count_lines, rolling.mean_times.rolling(window=num_window).mean(), label=f'Скользящее среднее по {num_window}ти замерам.')

    plt.ylabel(ylabel, fontsize=15)
    plt.xlabel(xlabel, fontsize=15)
    plt.title(title, fontsize=17)
    plt.legend(loc='upper left')
    plt.savefig('./graphics/need_time_{}_{}.png'.format(what, datetime.now().strftime("%d%m%Y_%H%M%S")))

plot_and_save_result(
    df=output,
    xlabel='Строк кода без пустых.',
    ylabel='Время, с.',
    title='Поиск схожих фрагментов различных работ с работой длиной в 100 строк.',
    what='gst',
    trend='n^2'
)

# %%
from utils import get_time_algorithms

output = get_time_algorithms(
    df.drop_duplicates(subset='count_lines_without_blank_lines', keep='last'),
    df[df.count_lines_without_blank_lines == 500].iloc[0],
    iterations=2,
    metric='gst'
)
# Out:
# ----------------------------------------
# Not compiled: https://github.com/python/cpython/blob/main/Lib/lib2to3/tests/data/py2_test_grammar.py
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
# In line 25
# In column 30
# ----------------------------------------
# ----------------------------------------
# Not compiled: https://github.com/python/cpython/blob/main/Lib/lib2to3/tests/data/py2_test_grammar.py
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
# In line 25
# In column 30
# ----------------------------------------
# 15683

# %%
plot_and_save_result(
    df=output,
    xlabel='Строк кода без пустых.',
    ylabel='Время, с.',
    title='Поиск схожих фрагментов различных работ с работой длиной в 500 строк.',
    what='gst',
    trend='n^2'
)

# %% [markdown]
# # Замер времени поиска схожих фрагментов работ с работами длиной 100 и 500 строк с помощью сравнение структур работ

# %%
from utils import get_time_algorithms

output = get_time_algorithms(
    df.drop_duplicates(subset='count_lines_without_blank_lines', keep='last'),
    df[df.count_lines_without_blank_lines == 100].iloc[0],
    iterations=1,
    metric='structure'
)
# Out:
# ----------------------------------------
# Not compiled: https://github.com/python/cpython/blob/main/Lib/lib2to3/tests/data/py2_test_grammar.py
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
# In line 25
# In column 30
# ----------------------------------------
# 15683

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from scipy.optimize import curve_fit
from datetime import datetime

def square_func(x, a, b, c):
    return a * x**2 + b * x + c

def cube_func(x, a, b, c, d):
    return a * x**3 + b * x**2 + c * x + d

def quart_func(x, a, b, c, d, e):
    return a * x**4 + b * x**3 + c * x**2 + d * x + e


def plot_and_save_result(df, xlabel, ylabel, title, what,
                         trend='linear'):
    # Simple Moving average
    unique_count_lines = np.unique(df.count_lines)
    mean_times = []
    for i in range(unique_count_lines.shape[0]):
        summ = 0
        count = 0
        for count_line, time in zip(df.count_lines, df.times):
            if unique_count_lines[i] == count_line:
                summ += time
                count += 1
        mean_times.append(summ / count)

    plt.figure(figsize=(12, 12), dpi=80)
    # plt.plot(unique_count_lines, mean_times, label='Среднее')

    if trend == 'linear':
        z = np.polyfit(unique_count_lines, mean_times, 1)
        p = np.poly1d(z)
        plt.plot(unique_count_lines, p(unique_count_lines),"r--", label='Линейный тренд.')
    elif trend == 'n^2':
        popt_cons, _ = curve_fit(square_func, unique_count_lines, mean_times, bounds=([-np.inf, 0., 0.], [np.inf, 0.1 ** 100, 0.1 ** 100]))
        p = np.poly1d(popt_cons)
        plt.plot(unique_count_lines, p(unique_count_lines),"r--", label='Квадратический тренд.')
    elif trend == 'n^3':
        popt_cons, _ = curve_fit(cube_func, unique_count_lines, mean_times, bounds=([-np.inf, 0., 0., 0.], [np.inf, 0.1 ** 100, 0.1 ** 100, 0.1 ** 100]))
        p = np.poly1d(popt_cons)
        print(p)
        plt.plot(unique_count_lines, p(unique_count_lines),"r--", label='Кубический тренд.')
    elif trend == 'n^4':
        popt_cons, _ = curve_fit(quart_func, unique_count_lines, mean_times, bounds=([-np.inf, 0., 0., 0., 0.], [np.inf, 0.1 ** 100, 0.1 ** 100, 0.1 ** 100, 0.1 ** 100]))
        p = np.poly1d(popt_cons)
        print(p)
        plt.plot(unique_count_lines, p(unique_count_lines),"r--", label='n^4.')

    rolling = pd.DataFrame(
        {
            'unique_count_lines': unique_count_lines,
            'mean_times': mean_times
        }
    )
    num_window = 20
    plt.plot(rolling.unique_count_lines, rolling.mean_times.rolling(window=num_window).mean(), label=f'Скользящее среднее по {num_window}ти замерам.')

    plt.ylabel(ylabel, fontsize=15)
    plt.xlabel(xlabel, fontsize=15)
    plt.title(title, fontsize=17)
    plt.legend(loc='upper left')
    plt.savefig('./graphics/need_time_{}_{}.png'.format(what, datetime.now().strftime("%d%m%Y_%H%M%S")))


plot_and_save_result(
    df=output,
    xlabel='Строк кода без пустых.',
    ylabel='Время, с.',
    title='Поиск схожих фрагментов различных работ с работой длиной в 100 строк.',
    what='structure',
    trend='linear'
)

# %%
from utils import get_time_algorithms

output = get_time_algorithms(
    df.drop_duplicates(subset='count_lines_without_blank_lines', keep='last'),
    df[df.count_lines_without_blank_lines == 500].iloc[0],
    iterations=2,
    metric='structure'
)
# Out:
# ----------------------------------------
# Not compiled: https://github.com/python/cpython/blob/main/Lib/lib2to3/tests/data/py2_test_grammar.py
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
# In line 25
# In column 30
# ----------------------------------------
# ----------------------------------------
# Not compiled: https://github.com/python/cpython/blob/main/Lib/lib2to3/tests/data/py2_test_grammar.py
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
# In line 25
# In column 30
# ----------------------------------------
# 15683

# %%
plot_and_save_result(
    df=output,
    xlabel='Строк кода без пустых.',
    ylabel='Время, с.',
    title='Поиск схожих фрагментов различных работ с работой длиной в 500 строк.',
    what='structure',
    trend='linear'
)

# %%
plot_and_save_result(
    df=output,
    xlabel='Строк кода без пустых.',
    ylabel='Время, с.',
    title='Поиск схожих фрагментов различных работ с работой длиной в 500 строк.',
    what='structure',
    trend='n^2'
)
